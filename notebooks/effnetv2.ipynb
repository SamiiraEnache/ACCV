# %%
# K-00 Run configuration
# Edit this cell before each Kaggle run.
# For a smoke-real-run, use DATASETS_TO_RUN = ["pathmnist"], PHASE1_EPOCHS = 1, PHASE2_EPOCHS = 1.
# For a valid Kaggle submission, use DATASETS_TO_RUN = "all".

RUN_NAME = "effv2s_weighted_ce"
DATASETS_TO_RUN = "all"  # "all" or list like ["pathmnist", "dermamnist"]

MODEL_NAME = "tf_efficientnetv2_s"          # "resnet18" | "efficientnetv2_s" | etc.
IMAGE_SIZE = 64
PHASE1_EPOCHS = 5
PHASE2_EPOCHS = 25
PATIENCE = 7

BACKBONE_LR = 1e-4
HEAD_LR = 1e-3
WEIGHT_DECAY = 1e-4
BATCH_SIZE = 128
AUG_LEVEL = "medium"             # "light" | "medium" | "heavy"

LOSS_TYPE = "cross_entropy"      # "cross_entropy" | "weighted_ce" | "focal"
FOCAL_GAMMA = 2.0

SCHEDULER = "cosine"             # "cosine" only; OneCycleLR needs per-batch stepping
USE_TRAINVAL = False             # True only for final small-dataset runs after tuning
TTA_ENABLED = True
SEED = 42

print(f"Run: {RUN_NAME}")
print(f"Datasets: {DATASETS_TO_RUN}")
print(f"Model: {MODEL_NAME} | Image size: {IMAGE_SIZE}")
print(f"Loss: {LOSS_TYPE} | Aug: {AUG_LEVEL}")
print(f"Phase1: {PHASE1_EPOCHS} | Phase2: {PHASE2_EPOCHS} | Patience: {PATIENCE}")
print(f"LR backbone: {BACKBONE_LR} | LR head: {HEAD_LR}")
# Out:
# Run: effv2s_weighted_ce
# Datasets: all
# Model: tf_efficientnetv2_s | Image size: 64
# Loss: cross_entropy | Aug: medium
# Phase1: 5 | Phase2: 25 | Patience: 7
# LR backbone: 0.0001 | LR head: 0.001

# %%
# K-01 Install dependencies and verify runtime
# Run once per Kaggle session.

import sys
import subprocess

subprocess.check_call([
    sys.executable,
    "-m",
    "pip",
    "install",
    "-q",
    "timm",
    "scikit-learn",
    "scipy",
    "pandas",
    "tqdm",
])

import torch
import timm

print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

model_check = timm.create_model("resnet18", pretrained=False, num_classes=2, in_chans=3)
print("timm OK — model creation works")
del model_check
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# GPU memory: 15.6 GB
# timm OK — model creation works

# %%
# K-02 Clone repository and import project modules
# The repo must be public OR Kaggle must have authenticated GitHub access.

import os
import sys
import subprocess
from pathlib import Path

REPO_NAME = "ACCV"
REPO_URL = "https://github.com/SamiiraEnache/ACCV.git"

WORKING_DIR = Path("/kaggle/working")
REPO_DIR = WORKING_DIR / REPO_NAME
WORKING_DIR.mkdir(parents=True, exist_ok=True)

if not REPO_DIR.exists():
    print(f"Cloning {REPO_URL} into {REPO_DIR} ...")
    subprocess.check_call(["git", "clone", REPO_URL, str(REPO_DIR)])
else:
    print(f"Repository already exists at {REPO_DIR}; pulling latest changes...")
    subprocess.check_call(["git", "-C", str(REPO_DIR), "pull"])

if str(REPO_DIR) not in sys.path:
    sys.path.insert(0, str(REPO_DIR))
os.chdir(REPO_DIR)

from configs.dataset_configs import DATASET_CONFIGS, FOCUS_TUNING_DATASETS, NO_VFLIP_DATASETS, SMALL_DATASETS
import configs.base_config as bc
from src.dataset import get_dataloaders
from src.transforms import get_train_transform, get_val_transform
from src.models import build_model, freeze_backbone, unfreeze_all, get_optimizer_phase2
from src.train import train_one_epoch, validate, compute_class_weights
from src.evaluate import predict_dataset, compute_harmonic_mean
from src.submission import build_submission_csv

print("All imports OK")
print(f"Repo cwd: {Path.cwd()}")
# Out:
# Cloning https://github.com/SamiiraEnache/ACCV.git into /kaggle/working/ACCV ...
# Cloning into '/kaggle/working/ACCV'...
# All imports OK
# Repo cwd: /kaggle/working/ACCV

# %%
# K-03 Reproducibility and output directories
# Also patch the Kaggle competition dataset path discovered during real execution.

import os
import random
from pathlib import Path
from datetime import datetime, UTC

import numpy as np
import pandas as pd
import torch
from scipy.stats import hmean
from sklearn.metrics import f1_score
from torch import nn
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
bc.BASE_CONFIG["device"] = DEVICE

CKPT_DIR = Path(f"/kaggle/working/checkpoints/{RUN_NAME}")
RESULTS_DIR = Path("/kaggle/working/results")
SUBMISSION_DIR = Path("/kaggle/working/submissions")

for directory in [CKPT_DIR, RESULTS_DIR, SUBMISSION_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print(f"Device: {DEVICE} | Seed: {SEED}")
print(f"Data root: {bc.BASE_CONFIG['data_root']}")
print(f"Checkpoint dir: {CKPT_DIR}")
print(f"Results dir: {RESULTS_DIR}")
print(f"Submission dir: {SUBMISSION_DIR}")

results_rows = []
# Out:
# Device: cuda | Seed: 42
# Data root: /kaggle/input/competitions/tensor-reloaded-multi-task-med-mnist/data/
# Checkpoint dir: /kaggle/working/checkpoints/effv2s_weighted_ce
# Results dir: /kaggle/working/results
# Submission dir: /kaggle/working/submissions

# %%
# K-04 Verify data access
# Confirms the selected datasets are present and readable.

required_keys = {"train_images", "train_labels", "val_images", "val_labels", "test_images"}

if DATASETS_TO_RUN == "all":
    datasets_list = list(DATASET_CONFIGS.keys())
else:
    datasets_list = list(DATASETS_TO_RUN)

print(f"Datasets selected: {datasets_list}")

for dataset_name in datasets_list:
    npz_path = Path(bc.BASE_CONFIG["data_root"]) / f"{dataset_name}.npz"
    assert npz_path.exists(), f"Missing dataset file: {npz_path}"

    with np.load(npz_path) as data:
        missing_keys = required_keys - set(data.files)
        assert not missing_keys, f"{dataset_name} missing keys: {missing_keys}"

        print(
            f"{dataset_name}: "
            f"train={data['train_images'].shape[0]:,} "
            f"val={data['val_images'].shape[0]:,} "
            f"test={data['test_images'].shape[0]:,} "
            f"shape={data['train_images'].shape[1:]}"
        )

print("Selected datasets present and readable.")
# Out:
# Datasets selected: ['pathmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist']
# pathmnist: train=89,996 val=10,004 test=7,180 shape=(28, 28, 3)
# dermamnist: train=7,007 val=1,003 test=2,005 shape=(28, 28, 3)
# octmnist: train=97,477 val=10,832 test=1,000 shape=(28, 28)
# pneumoniamnist: train=4,708 val=524 test=624 shape=(28, 28)
# retinamnist: train=1,080 val=120 test=400 shape=(28, 28, 3)
# breastmnist: train=546 val=78 test=156 shape=(28, 28)
# bloodmnist: train=11,959 val=1,712 test=3,421 shape=(28, 28, 3)
# tissuemnist: train=165,466 val=23,640 test=47,280 shape=(28, 28)
# organamnist: train=34,581 val=6,491 test=17,778 shape=(28, 28)
# organcmnist: train=13,000 val=2,392 test=8,268 shape=(28, 28)
# organsmnist: train=13,940 val=2,452 test=8,829 shape=(28, 28)
# Selected datasets present and readable.

# %%
# K-05 Training loop
# Trains all selected datasets independently and saves best + last checkpoints/probability arrays.

import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, gamma: float = 2.0, weight=None):
        super().__init__()
        self.gamma = gamma
        self.weight = weight

    def forward(self, logits, targets):
        ce = F.cross_entropy(logits, targets, weight=self.weight, reduction="none")
        pt = torch.exp(-ce)
        return (((1.0 - pt) ** self.gamma) * ce).mean()


def make_criterion(dataset_name: str, n_classes: int):
    npz_path = Path(bc.BASE_CONFIG["data_root"]) / f"{dataset_name}.npz"
    with np.load(npz_path) as data:
        labels = data["train_labels"]

    if LOSS_TYPE == "weighted_ce":
        weights = compute_class_weights(labels, n_classes).to(DEVICE)
        print(f"Loss: WeightedCE | weights={weights.detach().cpu().numpy().round(2)}")
        return nn.CrossEntropyLoss(weight=weights)

    if LOSS_TYPE == "focal":
        weights = compute_class_weights(labels, n_classes).to(DEVICE)
        print(f"Loss: FocalLoss(gamma={FOCAL_GAMMA}) with class weights")
        return FocalLoss(gamma=FOCAL_GAMMA, weight=weights)

    print("Loss: CrossEntropyLoss")
    return nn.CrossEntropyLoss()


all_predictions = {}
all_val_f1 = {}
training_outputs = {}

print(f"Training {len(datasets_list)} datasets: {datasets_list}")
print("=" * 80)

for ds_name in datasets_list:
    cfg = DATASET_CONFIGS[ds_name]
    print("\n" + "=" * 80)
    print(
        f"DATASET: {ds_name.upper()} | classes={cfg['n_classes']} | "
        f"imbalance={cfg['imbalance_ratio']:.1f}x"
    )
    print("=" * 80)

    train_tf = get_train_transform(IMAGE_SIZE, AUG_LEVEL, cfg["is_rgb"], ds_name)
    val_tf = get_val_transform(IMAGE_SIZE, cfg["is_rgb"])

    use_tv = USE_TRAINVAL and ds_name in SMALL_DATASETS
    train_loader, val_loader, test_loader = get_dataloaders(
        ds_name,
        IMAGE_SIZE,
        BATCH_SIZE,
        train_tf,
        val_tf,
        num_workers=2,
        use_trainval=use_tv,
    )

    print(
        f"Loaders ready | train={len(train_loader.dataset):,} "
        f"val={len(val_loader.dataset):,} test={len(test_loader.dataset):,}"
        + (" [train+val merged]" if use_tv else "")
    )

    criterion = make_criterion(ds_name, cfg["n_classes"])
    model = build_model(MODEL_NAME, cfg["n_classes"]).to(DEVICE)

    if PHASE1_EPOCHS > 0:
        freeze_backbone(model)
        opt_p1 = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, model.parameters()),
            lr=HEAD_LR,
            weight_decay=WEIGHT_DECAY,
        )

        print(f"\nPhase 1: {PHASE1_EPOCHS} epochs (frozen backbone)")
        for epoch in range(PHASE1_EPOCHS):
            tl, tf1 = train_one_epoch(model, train_loader, opt_p1, criterion, DEVICE)
            vl, vf1, _ = validate(model, val_loader, criterion, DEVICE)
            print(
                f"  [{ds_name}] P1 Ep {epoch + 1}/{PHASE1_EPOCHS} "
                f"| train_loss={tl:.4f} | train_f1={tf1:.4f} | val_f1={vf1:.4f}"
            )
    else:
        print("\nPhase 1 skipped (PHASE1_EPOCHS=0)")

    unfreeze_all(model)
    opt_p2 = get_optimizer_phase2(model, BACKBONE_LR, HEAD_LR, WEIGHT_DECAY)

    if SCHEDULER != "cosine":
        raise ValueError("Only cosine scheduler is enabled in this template.")
    scheduler = CosineAnnealingLR(opt_p2, T_max=max(PHASE2_EPOCHS, 1), eta_min=1e-6)

    best_val_f1 = -1.0
    best_epoch = 0
    epochs_no_improve = 0
    MIN_EPOCHS = min(10, PHASE2_EPOCHS)

    best_ckpt_path = CKPT_DIR / f"{ds_name}_best_val_f1.pth"
    last_ckpt_path = CKPT_DIR / f"{ds_name}_last_epoch.pth"

    print(f"\nPhase 2: {PHASE2_EPOCHS} epochs (full fine-tuning)")

    for epoch in range(PHASE2_EPOCHS):
        tl, tf1 = train_one_epoch(model, train_loader, opt_p2, criterion, DEVICE)
        vl, vf1, pc_f1 = validate(model, val_loader, criterion, DEVICE)

        scheduler.step()

        improved = vf1 > best_val_f1
        marker = " ← BEST" if improved else ""
        print(
            f"  [{ds_name}] P2 Ep {epoch + 1}/{PHASE2_EPOCHS} "
            f"| train_loss={tl:.4f} | train_f1={tf1:.4f} | "
            f"val_loss={vl:.4f} | val_f1={vf1:.4f}{marker}"
        )

        if improved:
            best_val_f1 = vf1
            best_epoch = epoch + 1
            epochs_no_improve = 0
            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "epoch": epoch + 1,
                    "val_f1": vf1,
                    "per_class_f1": pc_f1.tolist(),
                    "config": {
                        "run_name": RUN_NAME,
                        "dataset": ds_name,
                        "model": MODEL_NAME,
                        "image_size": IMAGE_SIZE,
                        "backbone_lr": BACKBONE_LR,
                        "head_lr": HEAD_LR,
                        "weight_decay": WEIGHT_DECAY,
                        "loss": LOSS_TYPE,
                        "aug_level": AUG_LEVEL,
                        "scheduler": SCHEDULER,
                    },
                },
                best_ckpt_path,
            )
        else:
            epochs_no_improve += 1

        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "epoch": epoch + 1,
                "val_f1": vf1,
            },
            last_ckpt_path,
        )

        if epochs_no_improve >= PATIENCE and (epoch + 1) >= MIN_EPOCHS:
            print(f"  Early stopping at epoch {epoch + 1}")
            break

    best_ckpt = torch.load(best_ckpt_path, map_location=DEVICE)
    model.load_state_dict(best_ckpt["model_state_dict"])
    model.eval()

    test_preds, test_probs_best = predict_dataset(model, test_loader, DEVICE)
    _, val_probs_best = predict_dataset(model, val_loader, DEVICE)

    np.save(CKPT_DIR / f"{ds_name}_test_probs_best.npy", test_probs_best)
    np.save(CKPT_DIR / f"{ds_name}_val_probs_best.npy", val_probs_best)

    last_ckpt = torch.load(last_ckpt_path, map_location=DEVICE)
    model.load_state_dict(last_ckpt["model_state_dict"])
    model.eval()
    _, test_probs_last = predict_dataset(model, test_loader, DEVICE)
    _, val_probs_last = predict_dataset(model, val_loader, DEVICE)

    np.save(CKPT_DIR / f"{ds_name}_test_probs_last.npy", test_probs_last)
    np.save(CKPT_DIR / f"{ds_name}_val_probs_last.npy", val_probs_last)

    model.load_state_dict(best_ckpt["model_state_dict"])
    model.eval()

    all_predictions[ds_name] = test_preds
    all_val_f1[ds_name] = best_val_f1

    training_outputs[ds_name] = {
        "checkpoint_path": str(best_ckpt_path),
        "last_checkpoint_path": str(last_ckpt_path),
        "test_loader": test_loader,
        "val_loader": val_loader,
        "best_val_f1": best_val_f1,
        "best_epoch": best_epoch,
    }

    test_f1_sanity = None
    npz_path = Path(bc.BASE_CONFIG["data_root"]) / f"{ds_name}.npz"
    with np.load(npz_path) as data:
        if "test_labels" in data.files:
            test_labels = data["test_labels"].squeeze()
            test_f1_sanity = f1_score(test_labels, test_preds, average="macro", zero_division=0)

    print(
        f"\n  [{ds_name}] FINAL | best_val_f1={best_val_f1:.4f} "
        f"| test_f1_sanity={test_f1_sanity if test_f1_sanity is not None else 'NA'}"
    )

    results_rows.append(
        {
            "dataset": ds_name,
            "model_name": MODEL_NAME,
            "image_size": IMAGE_SIZE,
            "lr_backbone": BACKBONE_LR,
            "lr_head": HEAD_LR,
            "weight_decay": WEIGHT_DECAY,
            "scheduler": SCHEDULER,
            "aug_level": AUG_LEVEL,
            "loss_type": LOSS_TYPE,
            "epochs": best_epoch,
            "val_macro_f1": round(float(best_val_f1), 4),
            "notes": RUN_NAME,
        }
    )

print("\n" + "=" * 80)
print("SELECTED DATASETS TRAINED")
print("=" * 80)
# Out:
# Training 11 datasets: ['pathmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist']
# ================================================================================
#
# ================================================================================
# DATASET: PATHMNIST | classes=9 | imbalance=1.6x
# ================================================================================
# Loaders ready | train=89,996 val=10,004 test=7,180
# Loss: CrossEntropyLoss
# model.safetensors:   0%|          | 0.00/86.5M [00:00<?, ?B/s]
# Phase 1: 5 epochs (frozen backbone)
#   [pathmnist] P1 Ep 1/5 | train_loss=3.6434 | train_f1=0.4763 | val_f1=0.5377
#   [pathmnist] P1 Ep 2/5 | train_loss=1.9018 | train_f1=0.6175 | val_f1=0.5965
#   [pathmnist] P1 Ep 3/5 | train_loss=1.4642 | train_f1=0.6517 | val_f1=0.6287
#   [pathmnist] P1 Ep 4/5 | train_loss=1.2046 | train_f1=0.6704 | val_f1=0.6582
#   [pathmnist] P1 Ep 5/5 | train_loss=1.0328 | train_f1=0.6883 | val_f1=0.6697
#
# Phase 2: 25 epochs (full fine-tuning)
#   [pathmnist] P2 Ep 1/25 | train_loss=0.4583 | train_f1=0.8444 | val_loss=0.2573 | val_f1=0.9108 ← BEST
#   [pathmnist] P2 Ep 2/25 | train_loss=0.2309 | train_f1=0.9201 | val_loss=0.1574 | val_f1=0.9477 ← BEST
#   [pathmnist] P2 Ep 3/25 | train_loss=0.1620 | train_f1=0.9435 | val_loss=0.1149 | val_f1=0.9622 ← BEST
#   [pathmnist] P2 Ep 4/25 | train_loss=0.1249 | train_f1=0.9570 | val_loss=0.0869 | val_f1=0.9711 ← BEST
#   [pathmnist] P2 Ep 5/25 | train_loss=0.1010 | train_f1=0.9652 | val_loss=0.0784 | val_f1=0.9738 ← BEST
#   [pathmnist] P2 Ep 6/25 | train_loss=0.0828 | train_f1=0.9721 | val_loss=0.0679 | val_f1=0.9780 ← BEST
#   [pathmnist] P2 Ep 7/25 | train_loss=0.0668 | train_f1=0.9775 | val_loss=0.0595 | val_f1=0.9815 ← BEST
#   [pathmnist] P2 Ep 8/25 | train_loss=0.0575 | train_f1=0.9803 | val_loss=0.0488 | val_f1=0.9842 ← BEST
#   [pathmnist] P2 Ep 9/25 | train_loss=0.0478 | train_f1=0.9836 | val_loss=0.0549 | val_f1=0.9839
#   [pathmnist] P2 Ep 10/25 | train_loss=0.0397 | train_f1=0.9864 | val_loss=0.0481 | val_f1=0.9850 ← BEST
#   [pathmnist] P2 Ep 11/25 | train_loss=0.0356 | train_f1=0.9876 | val_loss=0.0489 | val_f1=0.9860 ← BEST
#   [pathmnist] P2 Ep 12/25 | train_loss=0.0291 | train_f1=0.9901 | val_loss=0.0432 | val_f1=0.9883 ← BEST
#   [pathmnist] P2 Ep 13/25 | train_loss=0.0259 | train_f1=0.9912 | val_loss=0.0414 | val_f1=0.9874
#   [pathmnist] P2 Ep 14/25 | train_loss=0.0221 | train_f1=0.9926 | val_loss=0.0349 | val_f1=0.9896 ← BEST
#   [pathmnist] P2 Ep 15/25 | train_loss=0.0190 | train_f1=0.9938 | val_loss=0.0364 | val_f1=0.9886
#   [pathmnist] P2 Ep 16/25 | train_loss=0.0156 | train_f1=0.9946 | val_loss=0.0355 | val_f1=0.9905 ← BEST
#   [pathmnist] P2 Ep 17/25 | train_loss=0.0146 | train_f1=0.9951 | val_loss=0.0375 | val_f1=0.9880
#   [pathmnist] P2 Ep 18/25 | train_loss=0.0120 | train_f1=0.9961 | val_loss=0.0325 | val_f1=0.9901
#   [pathmnist] P2 Ep 19/25 | train_loss=0.0099 | train_f1=0.9968 | val_loss=0.0339 | val_f1=0.9902
#   [pathmnist] P2 Ep 20/25 | train_loss=0.0086 | train_f1=0.9971 | val_loss=0.0334 | val_f1=0.9909 ← BEST
#   [pathmnist] P2 Ep 21/25 | train_loss=0.0080 | train_f1=0.9973 | val_loss=0.0335 | val_f1=0.9909 ← BEST
#   [pathmnist] P2 Ep 22/25 | train_loss=0.0064 | train_f1=0.9980 | val_loss=0.0345 | val_f1=0.9906
#   [pathmnist] P2 Ep 23/25 | train_loss=0.0065 | train_f1=0.9981 | val_loss=0.0329 | val_f1=0.9912 ← BEST
#   [pathmnist] P2 Ep 24/25 | train_loss=0.0062 | train_f1=0.9979 | val_loss=0.0326 | val_f1=0.9917 ← BEST
#   [pathmnist] P2 Ep 25/25 | train_loss=0.0057 | train_f1=0.9982 | val_loss=0.0319 | val_f1=0.9915
#
#   [pathmnist] FINAL | best_val_f1=0.9917 | test_f1_sanity=0.9099182721991517
#
# ================================================================================
# DATASET: DERMAMNIST | classes=7 | imbalance=58.7x
# ================================================================================
# Loaders ready | train=7,007 val=1,003 test=2,005
# Loss: CrossEntropyLoss
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Phase 1: 5 epochs (frozen backbone)
#   [dermamnist] P1 Ep 1/5 | train_loss=6.2683 | train_f1=0.1568 | val_f1=0.1631
#   [dermamnist] P1 Ep 2/5 | train_loss=4.8133 | train_f1=0.1811 | val_f1=0.1669
#   [dermamnist] P1 Ep 3/5 | train_loss=4.3254 | train_f1=0.2001 | val_f1=0.1563
#   [dermamnist] P1 Ep 4/5 | train_loss=3.9212 | train_f1=0.2119 | val_f1=0.1698
#   [dermamnist] P1 Ep 5/5 | train_loss=3.7090 | train_f1=0.2233 | val_f1=0.1779
#
# Phase 2: 25 epochs (full fine-tuning)
#   [dermamnist] P2 Ep 1/25 | train_loss=2.9968 | train_f1=0.2520 | val_loss=2.3190 | val_f1=0.1861 ← BEST
#   [dermamnist] P2 Ep 2/25 | train_loss=1.7874 | train_f1=0.2976 | val_loss=1.5864 | val_f1=0.2049 ← BEST
#   [dermamnist] P2 Ep 3/25 | train_loss=1.3015 | train_f1=0.3129 | val_loss=1.1893 | val_f1=0.2235 ← BEST
#   [dermamnist] P2 Ep 4/25 | train_loss=1.0623 | train_f1=0.3413 | val_loss=1.1093 | val_f1=0.2164
#   [dermamnist] P2 Ep 5/25 | train_loss=0.9632 | train_f1=0.3542 | val_loss=1.0443 | val_f1=0.2401 ← BEST
#   [dermamnist] P2 Ep 6/25 | train_loss=0.8603 | train_f1=0.3889 | val_loss=1.0003 | val_f1=0.2437 ← BEST
#   [dermamnist] P2 Ep 7/25 | train_loss=0.8307 | train_f1=0.3974 | val_loss=0.9760 | val_f1=0.2603 ← BEST
#   [dermamnist] P2 Ep 8/25 | train_loss=0.7922 | train_f1=0.4010 | val_loss=0.9124 | val_f1=0.2664 ← BEST
#   [dermamnist] P2 Ep 9/25 | train_loss=0.7725 | train_f1=0.4084 | val_loss=0.8966 | val_f1=0.2924 ← BEST
#   [dermamnist] P2 Ep 10/25 | train_loss=0.7430 | train_f1=0.4150 | val_loss=0.8797 | val_f1=0.2965 ← BEST
#   [dermamnist] P2 Ep 11/25 | train_loss=0.7220 | train_f1=0.4596 | val_loss=0.8538 | val_f1=0.2923
#   [dermamnist] P2 Ep 12/25 | train_loss=0.7047 | train_f1=0.4536 | val_loss=0.8338 | val_f1=0.3028 ← BEST
#   [dermamnist] P2 Ep 13/25 | train_loss=0.6906 | train_f1=0.4705 | val_loss=0.8284 | val_f1=0.3252 ← BEST
#   [dermamnist] P2 Ep 14/25 | train_loss=0.6743 | train_f1=0.4936 | val_loss=0.8027 | val_f1=0.3555 ← BEST
#   [dermamnist] P2 Ep 15/25 | train_loss=0.6900 | train_f1=0.4711 | val_loss=0.8023 | val_f1=0.3415
#   [dermamnist] P2 Ep 16/25 | train_loss=0.6685 | train_f1=0.4977 | val_loss=0.7974 | val_f1=0.3511
#   [dermamnist] P2 Ep 17/25 | train_loss=0.6587 | train_f1=0.5123 | val_loss=0.7925 | val_f1=0.3439
#   [dermamnist] P2 Ep 18/25 | train_loss=0.6524 | train_f1=0.4940 | val_loss=0.7943 | val_f1=0.3512
#   [dermamnist] P2 Ep 19/25 | train_loss=0.6433 | train_f1=0.5110 | val_loss=0.7873 | val_f1=0.3436
#   [dermamnist] P2 Ep 20/25 | train_loss=0.6549 | train_f1=0.5126 | val_loss=0.7730 | val_f1=0.3665 ← BEST
#   [dermamnist] P2 Ep 21/25 | train_loss=0.6488 | train_f1=0.5161 | val_loss=0.7709 | val_f1=0.3630
#   [dermamnist] P2 Ep 22/25 | train_loss=0.6461 | train_f1=0.5126 | val_loss=0.7709 | val_f1=0.3602
#   [dermamnist] P2 Ep 23/25 | train_loss=0.6509 | train_f1=0.5209 | val_loss=0.7737 | val_f1=0.3662
#   [dermamnist] P2 Ep 24/25 | train_loss=0.6375 | train_f1=0.5167 | val_loss=0.7671 | val_f1=0.3691 ← BEST
#   [dermamnist] P2 Ep 25/25 | train_loss=0.6404 | train_f1=0.5219 | val_loss=0.7642 | val_f1=0.3641
#
#   [dermamnist] FINAL | best_val_f1=0.3691 | test_f1_sanity=0.3907831384702202
#
# ================================================================================
# DATASET: OCTMNIST | classes=4 | imbalance=5.9x
# ================================================================================
# Loaders ready | train=97,477 val=10,832 test=1,000
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [octmnist] P1 Ep 1/5 | train_loss=5.0019 | train_f1=0.3313 | val_f1=0.3502
#   [octmnist] P1 Ep 2/5 | train_loss=2.9099 | train_f1=0.3735 | val_f1=0.3736
#   [octmnist] P1 Ep 3/5 | train_loss=1.9966 | train_f1=0.3870 | val_f1=0.3887
#   [octmnist] P1 Ep 4/5 | train_loss=1.4204 | train_f1=0.4006 | val_f1=0.3941
#   [octmnist] P1 Ep 5/5 | train_loss=1.1157 | train_f1=0.4132 | val_f1=0.3987
#
# Phase 2: 25 epochs (full fine-tuning)
#   [octmnist] P2 Ep 1/25 | train_loss=0.5324 | train_f1=0.6447 | val_loss=0.3535 | val_f1=0.7570 ← BEST
#   [octmnist] P2 Ep 2/25 | train_loss=0.3456 | train_f1=0.7553 | val_loss=0.2951 | val_f1=0.7902 ← BEST
#   [octmnist] P2 Ep 3/25 | train_loss=0.2933 | train_f1=0.7954 | val_loss=0.2731 | val_f1=0.8134 ← BEST
#   [octmnist] P2 Ep 4/25 | train_loss=0.2616 | train_f1=0.8172 | val_loss=0.2452 | val_f1=0.8332 ← BEST
#   [octmnist] P2 Ep 5/25 | train_loss=0.2319 | train_f1=0.8410 | val_loss=0.2287 | val_f1=0.8488 ← BEST
#   [octmnist] P2 Ep 6/25 | train_loss=0.2079 | train_f1=0.8582 | val_loss=0.2193 | val_f1=0.8653 ← BEST
#   [octmnist] P2 Ep 7/25 | train_loss=0.1845 | train_f1=0.8743 | val_loss=0.2127 | val_f1=0.8653
#   [octmnist] P2 Ep 8/25 | train_loss=0.1618 | train_f1=0.8934 | val_loss=0.1989 | val_f1=0.8808 ← BEST
#   [octmnist] P2 Ep 9/25 | train_loss=0.1426 | train_f1=0.9053 | val_loss=0.1931 | val_f1=0.8819 ← BEST
#   [octmnist] P2 Ep 10/25 | train_loss=0.1198 | train_f1=0.9192 | val_loss=0.2039 | val_f1=0.8824 ← BEST
#   [octmnist] P2 Ep 11/25 | train_loss=0.1015 | train_f1=0.9321 | val_loss=0.2035 | val_f1=0.8932 ← BEST
#   [octmnist] P2 Ep 12/25 | train_loss=0.0841 | train_f1=0.9432 | val_loss=0.2107 | val_f1=0.8995 ← BEST
#   [octmnist] P2 Ep 13/25 | train_loss=0.0705 | train_f1=0.9534 | val_loss=0.2152 | val_f1=0.8982
#   [octmnist] P2 Ep 14/25 | train_loss=0.0572 | train_f1=0.9617 | val_loss=0.2348 | val_f1=0.8999 ← BEST
#   [octmnist] P2 Ep 15/25 | train_loss=0.0457 | train_f1=0.9694 | val_loss=0.2430 | val_f1=0.8987
#   [octmnist] P2 Ep 16/25 | train_loss=0.0381 | train_f1=0.9748 | val_loss=0.2461 | val_f1=0.8982
#   [octmnist] P2 Ep 17/25 | train_loss=0.0309 | train_f1=0.9796 | val_loss=0.2709 | val_f1=0.9025 ← BEST
#   [octmnist] P2 Ep 18/25 | train_loss=0.0253 | train_f1=0.9834 | val_loss=0.2927 | val_f1=0.9050 ← BEST
#   [octmnist] P2 Ep 19/25 | train_loss=0.0215 | train_f1=0.9854 | val_loss=0.2938 | val_f1=0.9063 ← BEST
#   [octmnist] P2 Ep 20/25 | train_loss=0.0176 | train_f1=0.9875 | val_loss=0.3037 | val_f1=0.9095 ← BEST
#   [octmnist] P2 Ep 21/25 | train_loss=0.0155 | train_f1=0.9888 | val_loss=0.3032 | val_f1=0.9081
#   [octmnist] P2 Ep 22/25 | train_loss=0.0130 | train_f1=0.9907 | val_loss=0.3095 | val_f1=0.9110 ← BEST
#   [octmnist] P2 Ep 23/25 | train_loss=0.0124 | train_f1=0.9908 | val_loss=0.3133 | val_f1=0.9106
#   [octmnist] P2 Ep 24/25 | train_loss=0.0115 | train_f1=0.9914 | val_loss=0.3145 | val_f1=0.9110 ← BEST
#   [octmnist] P2 Ep 25/25 | train_loss=0.0111 | train_f1=0.9920 | val_loss=0.3152 | val_f1=0.9122 ← BEST
#
#   [octmnist] FINAL | best_val_f1=0.9122 | test_f1_sanity=0.7259193190971246
#
# ================================================================================
# DATASET: PNEUMONIAMNIST | classes=2 | imbalance=2.9x
# ================================================================================
# Loaders ready | train=4,708 val=524 test=624
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [pneumoniamnist] P1 Ep 1/5 | train_loss=7.2910 | train_f1=0.4938 | val_f1=0.4296
#   [pneumoniamnist] P1 Ep 2/5 | train_loss=5.1984 | train_f1=0.5399 | val_f1=0.5063
#   [pneumoniamnist] P1 Ep 3/5 | train_loss=4.6812 | train_f1=0.5669 | val_f1=0.5074
#   [pneumoniamnist] P1 Ep 4/5 | train_loss=4.0972 | train_f1=0.6019 | val_f1=0.5265
#   [pneumoniamnist] P1 Ep 5/5 | train_loss=3.4923 | train_f1=0.6431 | val_f1=0.5216
#
# Phase 2: 25 epochs (full fine-tuning)
#   [pneumoniamnist] P2 Ep 1/25 | train_loss=1.9477 | train_f1=0.7799 | val_loss=1.0119 | val_f1=0.8461 ← BEST
#   [pneumoniamnist] P2 Ep 2/25 | train_loss=1.0332 | train_f1=0.8547 | val_loss=1.0033 | val_f1=0.8709 ← BEST
#   [pneumoniamnist] P2 Ep 3/25 | train_loss=0.7752 | train_f1=0.8725 | val_loss=0.6712 | val_f1=0.8341
#   [pneumoniamnist] P2 Ep 4/25 | train_loss=0.5551 | train_f1=0.8767 | val_loss=0.5988 | val_f1=0.8723 ← BEST
#   [pneumoniamnist] P2 Ep 5/25 | train_loss=0.4769 | train_f1=0.8803 | val_loss=0.4465 | val_f1=0.8928 ← BEST
#   [pneumoniamnist] P2 Ep 6/25 | train_loss=0.3557 | train_f1=0.8952 | val_loss=0.4739 | val_f1=0.8841
#   [pneumoniamnist] P2 Ep 7/25 | train_loss=0.2912 | train_f1=0.9054 | val_loss=0.3257 | val_f1=0.8759
#   [pneumoniamnist] P2 Ep 8/25 | train_loss=0.2794 | train_f1=0.9052 | val_loss=0.2483 | val_f1=0.9061 ← BEST
#   [pneumoniamnist] P2 Ep 9/25 | train_loss=0.2117 | train_f1=0.9144 | val_loss=0.2225 | val_f1=0.9119 ← BEST
#   [pneumoniamnist] P2 Ep 10/25 | train_loss=0.2477 | train_f1=0.9128 | val_loss=0.2378 | val_f1=0.9078
#   [pneumoniamnist] P2 Ep 11/25 | train_loss=0.1912 | train_f1=0.9225 | val_loss=0.2271 | val_f1=0.9086
#   [pneumoniamnist] P2 Ep 12/25 | train_loss=0.1856 | train_f1=0.9210 | val_loss=0.2260 | val_f1=0.9157 ← BEST
#   [pneumoniamnist] P2 Ep 13/25 | train_loss=0.1811 | train_f1=0.9265 | val_loss=0.1982 | val_f1=0.9213 ← BEST
#   [pneumoniamnist] P2 Ep 14/25 | train_loss=0.1548 | train_f1=0.9350 | val_loss=0.2126 | val_f1=0.9134
#   [pneumoniamnist] P2 Ep 15/25 | train_loss=0.1629 | train_f1=0.9314 | val_loss=0.2052 | val_f1=0.9153
#   [pneumoniamnist] P2 Ep 16/25 | train_loss=0.1469 | train_f1=0.9329 | val_loss=0.1930 | val_f1=0.9239 ← BEST
#   [pneumoniamnist] P2 Ep 17/25 | train_loss=0.1599 | train_f1=0.9357 | val_loss=0.1719 | val_f1=0.9381 ← BEST
#   [pneumoniamnist] P2 Ep 18/25 | train_loss=0.1461 | train_f1=0.9343 | val_loss=0.1699 | val_f1=0.9419 ← BEST
#   [pneumoniamnist] P2 Ep 19/25 | train_loss=0.1492 | train_f1=0.9272 | val_loss=0.1747 | val_f1=0.9288
#   [pneumoniamnist] P2 Ep 20/25 | train_loss=0.1377 | train_f1=0.9355 | val_loss=0.1755 | val_f1=0.9209
#   [pneumoniamnist] P2 Ep 21/25 | train_loss=0.1389 | train_f1=0.9331 | val_loss=0.1763 | val_f1=0.9305
#   [pneumoniamnist] P2 Ep 22/25 | train_loss=0.1338 | train_f1=0.9385 | val_loss=0.1731 | val_f1=0.9378
#   [pneumoniamnist] P2 Ep 23/25 | train_loss=0.1278 | train_f1=0.9452 | val_loss=0.1776 | val_f1=0.9217
#   [pneumoniamnist] P2 Ep 24/25 | train_loss=0.1338 | train_f1=0.9332 | val_loss=0.1681 | val_f1=0.9262
#   [pneumoniamnist] P2 Ep 25/25 | train_loss=0.1280 | train_f1=0.9343 | val_loss=0.1672 | val_f1=0.9375
#   Early stopping at epoch 25
#
#   [pneumoniamnist] FINAL | best_val_f1=0.9419 | test_f1_sanity=0.8230907197235344
#
# ================================================================================
# DATASET: RETINAMNIST | classes=5 | imbalance=7.4x
# ================================================================================
# Loaders ready | train=1,080 val=120 test=400
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [retinamnist] P1 Ep 1/5 | train_loss=9.8638 | train_f1=0.1881 | val_f1=0.1417
#   [retinamnist] P1 Ep 2/5 | train_loss=9.5842 | train_f1=0.1686 | val_f1=0.1568
#   [retinamnist] P1 Ep 3/5 | train_loss=8.8925 | train_f1=0.2095 | val_f1=0.2063
#   [retinamnist] P1 Ep 4/5 | train_loss=8.1919 | train_f1=0.2034 | val_f1=0.2441
#   [retinamnist] P1 Ep 5/5 | train_loss=8.1970 | train_f1=0.2155 | val_f1=0.2468
#
# Phase 2: 25 epochs (full fine-tuning)
#   [retinamnist] P2 Ep 1/25 | train_loss=7.1962 | train_f1=0.2692 | val_loss=6.3916 | val_f1=0.1746 ← BEST
#   [retinamnist] P2 Ep 2/25 | train_loss=6.4132 | train_f1=0.2804 | val_loss=5.0548 | val_f1=0.2640 ← BEST
#   [retinamnist] P2 Ep 3/25 | train_loss=5.2499 | train_f1=0.2945 | val_loss=4.2776 | val_f1=0.2318
#   [retinamnist] P2 Ep 4/25 | train_loss=4.8301 | train_f1=0.2950 | val_loss=3.5884 | val_f1=0.2438
#   [retinamnist] P2 Ep 5/25 | train_loss=4.3188 | train_f1=0.3000 | val_loss=3.2356 | val_f1=0.2653 ← BEST
#   [retinamnist] P2 Ep 6/25 | train_loss=3.8929 | train_f1=0.2908 | val_loss=2.8698 | val_f1=0.2493
#   [retinamnist] P2 Ep 7/25 | train_loss=3.5217 | train_f1=0.3015 | val_loss=2.5775 | val_f1=0.2869 ← BEST
#   [retinamnist] P2 Ep 8/25 | train_loss=3.0540 | train_f1=0.3162 | val_loss=2.3624 | val_f1=0.2670
#   [retinamnist] P2 Ep 9/25 | train_loss=2.7706 | train_f1=0.3171 | val_loss=2.1522 | val_f1=0.2931 ← BEST
#   [retinamnist] P2 Ep 10/25 | train_loss=2.6978 | train_f1=0.3059 | val_loss=2.2023 | val_f1=0.2660
#   [retinamnist] P2 Ep 11/25 | train_loss=2.2877 | train_f1=0.3372 | val_loss=2.1411 | val_f1=0.2595
#   [retinamnist] P2 Ep 12/25 | train_loss=2.3531 | train_f1=0.3438 | val_loss=2.0869 | val_f1=0.2663
#   [retinamnist] P2 Ep 13/25 | train_loss=2.2480 | train_f1=0.3145 | val_loss=2.0696 | val_f1=0.2707
#   [retinamnist] P2 Ep 14/25 | train_loss=2.2514 | train_f1=0.3026 | val_loss=2.0988 | val_f1=0.2524
#   [retinamnist] P2 Ep 15/25 | train_loss=2.0885 | train_f1=0.3056 | val_loss=2.0753 | val_f1=0.2335
#   [retinamnist] P2 Ep 16/25 | train_loss=2.0547 | train_f1=0.3205 | val_loss=2.0462 | val_f1=0.2216
#   Early stopping at epoch 16
#
#   [retinamnist] FINAL | best_val_f1=0.2931 | test_f1_sanity=0.22241462823014574
#
# ================================================================================
# DATASET: BREASTMNIST | classes=2 | imbalance=2.7x
# ================================================================================
# Loaders ready | train=546 val=78 test=156
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [breastmnist] P1 Ep 1/5 | train_loss=7.2756 | train_f1=0.4673 | val_f1=0.4046
#   [breastmnist] P1 Ep 2/5 | train_loss=6.8055 | train_f1=0.4906 | val_f1=0.3953
#   [breastmnist] P1 Ep 3/5 | train_loss=6.6470 | train_f1=0.4810 | val_f1=0.4889
#   [breastmnist] P1 Ep 4/5 | train_loss=6.6550 | train_f1=0.4895 | val_f1=0.5111
#   [breastmnist] P1 Ep 5/5 | train_loss=7.2130 | train_f1=0.4746 | val_f1=0.4701
#
# Phase 2: 25 epochs (full fine-tuning)
#   [breastmnist] P2 Ep 1/25 | train_loss=5.9993 | train_f1=0.5106 | val_loss=5.1586 | val_f1=0.4535 ← BEST
#   [breastmnist] P2 Ep 2/25 | train_loss=5.2019 | train_f1=0.5600 | val_loss=4.3345 | val_f1=0.4611 ← BEST
#   [breastmnist] P2 Ep 3/25 | train_loss=4.5516 | train_f1=0.5740 | val_loss=2.7691 | val_f1=0.5784 ← BEST
#   [breastmnist] P2 Ep 4/25 | train_loss=4.2191 | train_f1=0.5810 | val_loss=2.3283 | val_f1=0.6578 ← BEST
#   [breastmnist] P2 Ep 5/25 | train_loss=4.1241 | train_f1=0.5987 | val_loss=2.5817 | val_f1=0.6468
#   [breastmnist] P2 Ep 6/25 | train_loss=3.6845 | train_f1=0.6198 | val_loss=2.5203 | val_f1=0.6650 ← BEST
#   [breastmnist] P2 Ep 7/25 | train_loss=3.7308 | train_f1=0.6167 | val_loss=2.4955 | val_f1=0.6991 ← BEST
#   [breastmnist] P2 Ep 8/25 | train_loss=3.8877 | train_f1=0.6247 | val_loss=2.5557 | val_f1=0.6991
#   [breastmnist] P2 Ep 9/25 | train_loss=2.9701 | train_f1=0.6531 | val_loss=2.4888 | val_f1=0.6917
#   [breastmnist] P2 Ep 10/25 | train_loss=3.1511 | train_f1=0.6330 | val_loss=2.3196 | val_f1=0.6803
#   [breastmnist] P2 Ep 11/25 | train_loss=3.1381 | train_f1=0.6495 | val_loss=2.3962 | val_f1=0.6803
#   [breastmnist] P2 Ep 12/25 | train_loss=3.2443 | train_f1=0.6493 | val_loss=2.3289 | val_f1=0.6991
#   [breastmnist] P2 Ep 13/25 | train_loss=2.7681 | train_f1=0.6541 | val_loss=2.4660 | val_f1=0.6917
#   [breastmnist] P2 Ep 14/25 | train_loss=2.9629 | train_f1=0.6746 | val_loss=2.4266 | val_f1=0.7292 ← BEST
#   [breastmnist] P2 Ep 15/25 | train_loss=2.8201 | train_f1=0.6589 | val_loss=2.3137 | val_f1=0.6917
#   [breastmnist] P2 Ep 16/25 | train_loss=2.7340 | train_f1=0.6716 | val_loss=2.4101 | val_f1=0.7033
#   [breastmnist] P2 Ep 17/25 | train_loss=2.7099 | train_f1=0.6853 | val_loss=2.3795 | val_f1=0.7033
#   [breastmnist] P2 Ep 18/25 | train_loss=2.7986 | train_f1=0.6836 | val_loss=2.5670 | val_f1=0.6917
#   [breastmnist] P2 Ep 19/25 | train_loss=2.4200 | train_f1=0.6731 | val_loss=2.5947 | val_f1=0.7107
#   [breastmnist] P2 Ep 20/25 | train_loss=2.4327 | train_f1=0.7149 | val_loss=2.4634 | val_f1=0.6416
#   [breastmnist] P2 Ep 21/25 | train_loss=2.2149 | train_f1=0.6992 | val_loss=2.4742 | val_f1=0.6408
#   Early stopping at epoch 21
#
#   [breastmnist] FINAL | best_val_f1=0.7292 | test_f1_sanity=0.5683794466403163
#
# ================================================================================
# DATASET: BLOODMNIST | classes=8 | imbalance=2.7x
# ================================================================================
# Loaders ready | train=11,959 val=1,712 test=3,421
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [bloodmnist] P1 Ep 1/5 | train_loss=7.6041 | train_f1=0.1967 | val_f1=0.2244
#   [bloodmnist] P1 Ep 2/5 | train_loss=5.0137 | train_f1=0.3183 | val_f1=0.2777
#   [bloodmnist] P1 Ep 3/5 | train_loss=3.9647 | train_f1=0.3848 | val_f1=0.3119
#   [bloodmnist] P1 Ep 4/5 | train_loss=3.4049 | train_f1=0.4261 | val_f1=0.3560
#   [bloodmnist] P1 Ep 5/5 | train_loss=3.0643 | train_f1=0.4635 | val_f1=0.3671
#
# Phase 2: 25 epochs (full fine-tuning)
#   [bloodmnist] P2 Ep 1/25 | train_loss=1.6858 | train_f1=0.6120 | val_loss=1.1550 | val_f1=0.6122 ← BEST
#   [bloodmnist] P2 Ep 2/25 | train_loss=0.7289 | train_f1=0.7485 | val_loss=0.7167 | val_f1=0.7368 ← BEST
#   [bloodmnist] P2 Ep 3/25 | train_loss=0.4789 | train_f1=0.8029 | val_loss=0.5062 | val_f1=0.7848 ← BEST
#   [bloodmnist] P2 Ep 4/25 | train_loss=0.3975 | train_f1=0.8356 | val_loss=0.4350 | val_f1=0.8231 ← BEST
#   [bloodmnist] P2 Ep 5/25 | train_loss=0.3240 | train_f1=0.8587 | val_loss=0.3690 | val_f1=0.8501 ← BEST
#   [bloodmnist] P2 Ep 6/25 | train_loss=0.2887 | train_f1=0.8796 | val_loss=0.3184 | val_f1=0.8790 ← BEST
#   [bloodmnist] P2 Ep 7/25 | train_loss=0.2705 | train_f1=0.8915 | val_loss=0.2897 | val_f1=0.8873 ← BEST
#   [bloodmnist] P2 Ep 8/25 | train_loss=0.2353 | train_f1=0.9027 | val_loss=0.2641 | val_f1=0.8928 ← BEST
#   [bloodmnist] P2 Ep 9/25 | train_loss=0.2109 | train_f1=0.9110 | val_loss=0.2459 | val_f1=0.9010 ← BEST
#   [bloodmnist] P2 Ep 10/25 | train_loss=0.1940 | train_f1=0.9196 | val_loss=0.2274 | val_f1=0.9102 ← BEST
#   [bloodmnist] P2 Ep 11/25 | train_loss=0.1819 | train_f1=0.9249 | val_loss=0.2126 | val_f1=0.9208 ← BEST
#   [bloodmnist] P2 Ep 12/25 | train_loss=0.1773 | train_f1=0.9290 | val_loss=0.1908 | val_f1=0.9276 ← BEST
#   [bloodmnist] P2 Ep 13/25 | train_loss=0.1620 | train_f1=0.9346 | val_loss=0.1970 | val_f1=0.9260
#   [bloodmnist] P2 Ep 14/25 | train_loss=0.1538 | train_f1=0.9337 | val_loss=0.1887 | val_f1=0.9231
#   [bloodmnist] P2 Ep 15/25 | train_loss=0.1477 | train_f1=0.9382 | val_loss=0.1833 | val_f1=0.9319 ← BEST
#   [bloodmnist] P2 Ep 16/25 | train_loss=0.1467 | train_f1=0.9401 | val_loss=0.1751 | val_f1=0.9289
#   [bloodmnist] P2 Ep 17/25 | train_loss=0.1452 | train_f1=0.9411 | val_loss=0.1723 | val_f1=0.9322 ← BEST
#   [bloodmnist] P2 Ep 18/25 | train_loss=0.1381 | train_f1=0.9436 | val_loss=0.1585 | val_f1=0.9366 ← BEST
#   [bloodmnist] P2 Ep 19/25 | train_loss=0.1278 | train_f1=0.9494 | val_loss=0.1732 | val_f1=0.9337
#   [bloodmnist] P2 Ep 20/25 | train_loss=0.1257 | train_f1=0.9476 | val_loss=0.1555 | val_f1=0.9420 ← BEST
#   [bloodmnist] P2 Ep 21/25 | train_loss=0.1223 | train_f1=0.9507 | val_loss=0.1575 | val_f1=0.9379
#   [bloodmnist] P2 Ep 22/25 | train_loss=0.1217 | train_f1=0.9521 | val_loss=0.1528 | val_f1=0.9382
#   [bloodmnist] P2 Ep 23/25 | train_loss=0.1128 | train_f1=0.9559 | val_loss=0.1502 | val_f1=0.9387
#   [bloodmnist] P2 Ep 24/25 | train_loss=0.1229 | train_f1=0.9512 | val_loss=0.1515 | val_f1=0.9373
#   [bloodmnist] P2 Ep 25/25 | train_loss=0.1164 | train_f1=0.9531 | val_loss=0.1507 | val_f1=0.9424 ← BEST
#
#   [bloodmnist] FINAL | best_val_f1=0.9424 | test_f1_sanity=0.940778050889955
#
# ================================================================================
# DATASET: TISSUEMNIST | classes=8 | imbalance=9.0x
# ================================================================================
# Loaders ready | train=165,466 val=23,640 test=47,280
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [tissuemnist] P1 Ep 1/5 | train_loss=4.3449 | train_f1=0.2254 | val_f1=0.2332
#   [tissuemnist] P1 Ep 2/5 | train_loss=2.1676 | train_f1=0.2603 | val_f1=0.2617
#   [tissuemnist] P1 Ep 3/5 | train_loss=1.6363 | train_f1=0.2797 | val_f1=0.2697
#   [tissuemnist] P1 Ep 4/5 | train_loss=1.5250 | train_f1=0.2892 | val_f1=0.2655
#   [tissuemnist] P1 Ep 5/5 | train_loss=1.5094 | train_f1=0.2879 | val_f1=0.2740
#
# Phase 2: 25 epochs (full fine-tuning)
#   [tissuemnist] P2 Ep 1/25 | train_loss=1.1343 | train_f1=0.4500 | val_loss=0.9960 | val_f1=0.5081 ← BEST
#   [tissuemnist] P2 Ep 2/25 | train_loss=0.9478 | train_f1=0.5439 | val_loss=0.8984 | val_f1=0.5684 ← BEST
#   [tissuemnist] P2 Ep 3/25 | train_loss=0.8728 | train_f1=0.5881 | val_loss=0.8515 | val_f1=0.5962 ← BEST
#   [tissuemnist] P2 Ep 4/25 | train_loss=0.8230 | train_f1=0.6106 | val_loss=0.8349 | val_f1=0.6083 ← BEST
#   [tissuemnist] P2 Ep 5/25 | train_loss=0.7808 | train_f1=0.6340 | val_loss=0.8096 | val_f1=0.6256 ← BEST
#   [tissuemnist] P2 Ep 6/25 | train_loss=0.7413 | train_f1=0.6521 | val_loss=0.7959 | val_f1=0.6349 ← BEST
#   [tissuemnist] P2 Ep 7/25 | train_loss=0.7011 | train_f1=0.6712 | val_loss=0.8041 | val_f1=0.6306
#   [tissuemnist] P2 Ep 8/25 | train_loss=0.6577 | train_f1=0.6903 | val_loss=0.7959 | val_f1=0.6423 ← BEST
#   [tissuemnist] P2 Ep 9/25 | train_loss=0.6132 | train_f1=0.7108 | val_loss=0.8279 | val_f1=0.6301
#   [tissuemnist] P2 Ep 10/25 | train_loss=0.5631 | train_f1=0.7352 | val_loss=0.8538 | val_f1=0.6267
#   [tissuemnist] P2 Ep 11/25 | train_loss=0.5112 | train_f1=0.7590 | val_loss=0.8790 | val_f1=0.6230
#   [tissuemnist] P2 Ep 12/25 | train_loss=0.4613 | train_f1=0.7846 | val_loss=0.9549 | val_f1=0.6230
#   [tissuemnist] P2 Ep 13/25 | train_loss=0.4125 | train_f1=0.8081 | val_loss=0.9933 | val_f1=0.6255
#   [tissuemnist] P2 Ep 14/25 | train_loss=0.3641 | train_f1=0.8322 | val_loss=1.0245 | val_f1=0.6212
#   [tissuemnist] P2 Ep 15/25 | train_loss=0.3233 | train_f1=0.8521 | val_loss=1.0997 | val_f1=0.6115
#   Early stopping at epoch 15
#
#   [tissuemnist] FINAL | best_val_f1=0.6423 | test_f1_sanity=0.635716216795388
#
# ================================================================================
# DATASET: ORGANAMNIST | classes=11 | imbalance=4.5x
# ================================================================================
# Loaders ready | train=34,581 val=6,491 test=17,778
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [organamnist] P1 Ep 1/5 | train_loss=4.5253 | train_f1=0.3393 | val_f1=0.4794
#   [organamnist] P1 Ep 2/5 | train_loss=2.4364 | train_f1=0.5269 | val_f1=0.5636
#   [organamnist] P1 Ep 3/5 | train_loss=1.9178 | train_f1=0.5822 | val_f1=0.6160
#   [organamnist] P1 Ep 4/5 | train_loss=1.6755 | train_f1=0.6167 | val_f1=0.6511
#   [organamnist] P1 Ep 5/5 | train_loss=1.4563 | train_f1=0.6376 | val_f1=0.6639
#
# Phase 2: 25 epochs (full fine-tuning)
#   [organamnist] P2 Ep 1/25 | train_loss=0.5625 | train_f1=0.8175 | val_loss=0.2432 | val_f1=0.9222 ← BEST
#   [organamnist] P2 Ep 2/25 | train_loss=0.1763 | train_f1=0.9363 | val_loss=0.1584 | val_f1=0.9575 ← BEST
#   [organamnist] P2 Ep 3/25 | train_loss=0.0962 | train_f1=0.9650 | val_loss=0.1238 | val_f1=0.9664 ← BEST
#   [organamnist] P2 Ep 4/25 | train_loss=0.0569 | train_f1=0.9793 | val_loss=0.1125 | val_f1=0.9716 ← BEST
#   [organamnist] P2 Ep 5/25 | train_loss=0.0368 | train_f1=0.9866 | val_loss=0.0936 | val_f1=0.9763 ← BEST
#   [organamnist] P2 Ep 6/25 | train_loss=0.0275 | train_f1=0.9902 | val_loss=0.0941 | val_f1=0.9768 ← BEST
#   [organamnist] P2 Ep 7/25 | train_loss=0.0200 | train_f1=0.9923 | val_loss=0.0912 | val_f1=0.9816 ← BEST
#   [organamnist] P2 Ep 8/25 | train_loss=0.0135 | train_f1=0.9952 | val_loss=0.0672 | val_f1=0.9840 ← BEST
#   [organamnist] P2 Ep 9/25 | train_loss=0.0125 | train_f1=0.9951 | val_loss=0.0700 | val_f1=0.9811
#   [organamnist] P2 Ep 10/25 | train_loss=0.0094 | train_f1=0.9967 | val_loss=0.0945 | val_f1=0.9784
#   [organamnist] P2 Ep 11/25 | train_loss=0.0078 | train_f1=0.9967 | val_loss=0.0781 | val_f1=0.9821
#   [organamnist] P2 Ep 12/25 | train_loss=0.0067 | train_f1=0.9973 | val_loss=0.0758 | val_f1=0.9837
#   [organamnist] P2 Ep 13/25 | train_loss=0.0049 | train_f1=0.9979 | val_loss=0.0766 | val_f1=0.9818
#   [organamnist] P2 Ep 14/25 | train_loss=0.0047 | train_f1=0.9984 | val_loss=0.0613 | val_f1=0.9846 ← BEST
#   [organamnist] P2 Ep 15/25 | train_loss=0.0051 | train_f1=0.9979 | val_loss=0.0968 | val_f1=0.9812
#   [organamnist] P2 Ep 16/25 | train_loss=0.0033 | train_f1=0.9989 | val_loss=0.1044 | val_f1=0.9802
#   [organamnist] P2 Ep 17/25 | train_loss=0.0040 | train_f1=0.9983 | val_loss=0.1079 | val_f1=0.9839
#   [organamnist] P2 Ep 18/25 | train_loss=0.0024 | train_f1=0.9990 | val_loss=0.1036 | val_f1=0.9842
#   [organamnist] P2 Ep 19/25 | train_loss=0.0022 | train_f1=0.9990 | val_loss=0.1090 | val_f1=0.9825
#   [organamnist] P2 Ep 20/25 | train_loss=0.0016 | train_f1=0.9995 | val_loss=0.1027 | val_f1=0.9834
#   [organamnist] P2 Ep 21/25 | train_loss=0.0018 | train_f1=0.9992 | val_loss=0.0931 | val_f1=0.9847 ← BEST
#   [organamnist] P2 Ep 22/25 | train_loss=0.0016 | train_f1=0.9994 | val_loss=0.0743 | val_f1=0.9865 ← BEST
#   [organamnist] P2 Ep 23/25 | train_loss=0.0013 | train_f1=0.9995 | val_loss=0.0792 | val_f1=0.9858
#   [organamnist] P2 Ep 24/25 | train_loss=0.0011 | train_f1=0.9995 | val_loss=0.0846 | val_f1=0.9857
#   [organamnist] P2 Ep 25/25 | train_loss=0.0011 | train_f1=0.9996 | val_loss=0.0800 | val_f1=0.9864
#
#   [organamnist] FINAL | best_val_f1=0.9865 | test_f1_sanity=0.938400713644808
#
# ================================================================================
# DATASET: ORGANCMNIST | classes=11 | imbalance=5.0x
# ================================================================================
# Loaders ready | train=13,000 val=2,392 test=8,268
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [organcmnist] P1 Ep 1/5 | train_loss=7.1578 | train_f1=0.1609 | val_f1=0.2556
#   [organcmnist] P1 Ep 2/5 | train_loss=4.4725 | train_f1=0.3204 | val_f1=0.3560
#   [organcmnist] P1 Ep 3/5 | train_loss=3.4475 | train_f1=0.4039 | val_f1=0.4348
#   [organcmnist] P1 Ep 4/5 | train_loss=3.0237 | train_f1=0.4451 | val_f1=0.4736
#   [organcmnist] P1 Ep 5/5 | train_loss=2.6130 | train_f1=0.4821 | val_f1=0.5253
#
# Phase 2: 25 epochs (full fine-tuning)
#   [organcmnist] P2 Ep 1/25 | train_loss=1.4104 | train_f1=0.6392 | val_loss=0.6098 | val_f1=0.7769 ← BEST
#   [organcmnist] P2 Ep 2/25 | train_loss=0.5722 | train_f1=0.7970 | val_loss=0.3031 | val_f1=0.8936 ← BEST
#   [organcmnist] P2 Ep 3/25 | train_loss=0.3487 | train_f1=0.8588 | val_loss=0.2180 | val_f1=0.9266 ← BEST
#   [organcmnist] P2 Ep 4/25 | train_loss=0.2504 | train_f1=0.8957 | val_loss=0.2126 | val_f1=0.9291 ← BEST
#   [organcmnist] P2 Ep 5/25 | train_loss=0.1976 | train_f1=0.9223 | val_loss=0.1718 | val_f1=0.9455 ← BEST
#   [organcmnist] P2 Ep 6/25 | train_loss=0.1491 | train_f1=0.9388 | val_loss=0.1669 | val_f1=0.9486 ← BEST
#   [organcmnist] P2 Ep 7/25 | train_loss=0.1242 | train_f1=0.9494 | val_loss=0.1559 | val_f1=0.9583 ← BEST
#   [organcmnist] P2 Ep 8/25 | train_loss=0.1049 | train_f1=0.9540 | val_loss=0.1699 | val_f1=0.9561
#   [organcmnist] P2 Ep 9/25 | train_loss=0.0824 | train_f1=0.9638 | val_loss=0.1680 | val_f1=0.9570
#   [organcmnist] P2 Ep 10/25 | train_loss=0.0753 | train_f1=0.9669 | val_loss=0.1634 | val_f1=0.9615 ← BEST
#   [organcmnist] P2 Ep 11/25 | train_loss=0.0583 | train_f1=0.9759 | val_loss=0.1605 | val_f1=0.9627 ← BEST
#   [organcmnist] P2 Ep 12/25 | train_loss=0.0453 | train_f1=0.9804 | val_loss=0.1547 | val_f1=0.9665 ← BEST
#   [organcmnist] P2 Ep 13/25 | train_loss=0.0461 | train_f1=0.9806 | val_loss=0.1515 | val_f1=0.9650
#   [organcmnist] P2 Ep 14/25 | train_loss=0.0413 | train_f1=0.9818 | val_loss=0.1458 | val_f1=0.9688 ← BEST
#   [organcmnist] P2 Ep 15/25 | train_loss=0.0371 | train_f1=0.9852 | val_loss=0.1552 | val_f1=0.9640
#   [organcmnist] P2 Ep 16/25 | train_loss=0.0326 | train_f1=0.9859 | val_loss=0.1502 | val_f1=0.9687
#   [organcmnist] P2 Ep 17/25 | train_loss=0.0271 | train_f1=0.9887 | val_loss=0.1393 | val_f1=0.9730 ← BEST
#   [organcmnist] P2 Ep 18/25 | train_loss=0.0283 | train_f1=0.9884 | val_loss=0.1466 | val_f1=0.9703
#   [organcmnist] P2 Ep 19/25 | train_loss=0.0240 | train_f1=0.9899 | val_loss=0.1458 | val_f1=0.9703
#   [organcmnist] P2 Ep 20/25 | train_loss=0.0245 | train_f1=0.9896 | val_loss=0.1406 | val_f1=0.9708
#   [organcmnist] P2 Ep 21/25 | train_loss=0.0217 | train_f1=0.9912 | val_loss=0.1453 | val_f1=0.9725
#   [organcmnist] P2 Ep 22/25 | train_loss=0.0216 | train_f1=0.9908 | val_loss=0.1437 | val_f1=0.9724
#   [organcmnist] P2 Ep 23/25 | train_loss=0.0223 | train_f1=0.9909 | val_loss=0.1495 | val_f1=0.9698
#   [organcmnist] P2 Ep 24/25 | train_loss=0.0209 | train_f1=0.9916 | val_loss=0.1513 | val_f1=0.9708
#   Early stopping at epoch 24
#
#   [organcmnist] FINAL | best_val_f1=0.9730 | test_f1_sanity=0.8870998507850568
#
# ================================================================================
# DATASET: ORGANSMNIST | classes=11 | imbalance=5.6x
# ================================================================================
# Loaders ready | train=13,940 val=2,452 test=8,829
# Loss: CrossEntropyLoss
#
# Phase 1: 5 epochs (frozen backbone)
#   [organsmnist] P1 Ep 1/5 | train_loss=6.8464 | train_f1=0.1588 | val_f1=0.2390
#   [organsmnist] P1 Ep 2/5 | train_loss=4.5328 | train_f1=0.2915 | val_f1=0.3134
#   [organsmnist] P1 Ep 3/5 | train_loss=3.6609 | train_f1=0.3559 | val_f1=0.3811
#   [organsmnist] P1 Ep 4/5 | train_loss=3.2626 | train_f1=0.3917 | val_f1=0.4062
#   [organsmnist] P1 Ep 5/5 | train_loss=2.9147 | train_f1=0.4205 | val_f1=0.4356
#
# Phase 2: 25 epochs (full fine-tuning)
#   [organsmnist] P2 Ep 1/25 | train_loss=1.8132 | train_f1=0.5305 | val_loss=0.9875 | val_f1=0.6665 ← BEST
#   [organsmnist] P2 Ep 2/25 | train_loss=0.8699 | train_f1=0.6576 | val_loss=0.5857 | val_f1=0.7286 ← BEST
#   [organsmnist] P2 Ep 3/25 | train_loss=0.6219 | train_f1=0.7192 | val_loss=0.4832 | val_f1=0.7702 ← BEST
#   [organsmnist] P2 Ep 4/25 | train_loss=0.4974 | train_f1=0.7697 | val_loss=0.3942 | val_f1=0.7933 ← BEST
#   [organsmnist] P2 Ep 5/25 | train_loss=0.4121 | train_f1=0.8002 | val_loss=0.3587 | val_f1=0.8123 ← BEST
#   [organsmnist] P2 Ep 6/25 | train_loss=0.3529 | train_f1=0.8183 | val_loss=0.3505 | val_f1=0.8101
#   [organsmnist] P2 Ep 7/25 | train_loss=0.3138 | train_f1=0.8393 | val_loss=0.3447 | val_f1=0.8246 ← BEST
#   [organsmnist] P2 Ep 8/25 | train_loss=0.2676 | train_f1=0.8569 | val_loss=0.3177 | val_f1=0.8238
#   [organsmnist] P2 Ep 9/25 | train_loss=0.2363 | train_f1=0.8704 | val_loss=0.3197 | val_f1=0.8317 ← BEST
#   [organsmnist] P2 Ep 10/25 | train_loss=0.2091 | train_f1=0.8883 | val_loss=0.3283 | val_f1=0.8242
#   [organsmnist] P2 Ep 11/25 | train_loss=0.1866 | train_f1=0.8945 | val_loss=0.3246 | val_f1=0.8265
#   [organsmnist] P2 Ep 12/25 | train_loss=0.1728 | train_f1=0.9037 | val_loss=0.3194 | val_f1=0.8375 ← BEST
#   [organsmnist] P2 Ep 13/25 | train_loss=0.1469 | train_f1=0.9150 | val_loss=0.3027 | val_f1=0.8390 ← BEST
#   [organsmnist] P2 Ep 14/25 | train_loss=0.1345 | train_f1=0.9212 | val_loss=0.3381 | val_f1=0.8279
#   [organsmnist] P2 Ep 15/25 | train_loss=0.1193 | train_f1=0.9278 | val_loss=0.3465 | val_f1=0.8371
#   [organsmnist] P2 Ep 16/25 | train_loss=0.1130 | train_f1=0.9335 | val_loss=0.3486 | val_f1=0.8350
#   [organsmnist] P2 Ep 17/25 | train_loss=0.1034 | train_f1=0.9360 | val_loss=0.3440 | val_f1=0.8441 ← BEST
#   [organsmnist] P2 Ep 18/25 | train_loss=0.0945 | train_f1=0.9432 | val_loss=0.3680 | val_f1=0.8379
#   [organsmnist] P2 Ep 19/25 | train_loss=0.0868 | train_f1=0.9479 | val_loss=0.3493 | val_f1=0.8407
#   [organsmnist] P2 Ep 20/25 | train_loss=0.0841 | train_f1=0.9489 | val_loss=0.3744 | val_f1=0.8356
#   [organsmnist] P2 Ep 21/25 | train_loss=0.0784 | train_f1=0.9548 | val_loss=0.3583 | val_f1=0.8435
#   [organsmnist] P2 Ep 22/25 | train_loss=0.0747 | train_f1=0.9573 | val_loss=0.3521 | val_f1=0.8420
#   [organsmnist] P2 Ep 23/25 | train_loss=0.0759 | train_f1=0.9537 | val_loss=0.3590 | val_f1=0.8440
#   [organsmnist] P2 Ep 24/25 | train_loss=0.0744 | train_f1=0.9585 | val_loss=0.3546 | val_f1=0.8363
#   Early stopping at epoch 24
#
#   [organsmnist] FINAL | best_val_f1=0.8441 | test_f1_sanity=0.7506157354730121
#
# ================================================================================
# SELECTED DATASETS TRAINED
# ================================================================================

# %%
# K-06 Harmonic mean summary
# For partial runs, this is the harmonic mean over the selected datasets only.

print("\nPer-dataset validation F1:")
print("-" * 50)

for ds, score in all_val_f1.items():
    flag = " ← WEAK" if score < 0.70 else ""
    print(f"  {ds:<18} {score:.4f}{flag}")

if len(all_val_f1) > 0 and all(score > 0 for score in all_val_f1.values()):
    harmonic_mean_f1 = float(hmean(list(all_val_f1.values())))
else:
    harmonic_mean_f1 = 0.0

arithmetic_mean_f1 = float(np.mean(list(all_val_f1.values()))) if all_val_f1 else 0.0

print("-" * 50)
print(f"  HARMONIC MEAN:    {harmonic_mean_f1:.4f}")
print(f"  ARITHMETIC MEAN:  {arithmetic_mean_f1:.4f}")
print("\nNote: final competition metric requires all 11 datasets.")
# Out:
# Per-dataset validation F1:
# --------------------------------------------------
#   pathmnist          0.9917
#   dermamnist         0.3691 ← WEAK
#   octmnist           0.9122
#   pneumoniamnist     0.9419
#   retinamnist        0.2931 ← WEAK
#   breastmnist        0.7292
#   bloodmnist         0.9424
#   tissuemnist        0.6423 ← WEAK
#   organamnist        0.9865
#   organcmnist        0.9730
#   organsmnist        0.8441
# --------------------------------------------------
#   HARMONIC MEAN:    0.6665
#   ARITHMETIC MEAN:  0.7841
#
# Note: final competition metric requires all 11 datasets.

# %%
# K-07 Submission CSV
# TTA averages softmax probabilities across deterministic image variants.
# For partial smoke runs, final Kaggle submission CSV is skipped because competition submissions require all 11 datasets.

def load_best_model(dataset_name):
    model = build_model(MODEL_NAME, DATASET_CONFIGS[dataset_name]["n_classes"])
    checkpoint = torch.load(training_outputs[dataset_name]["checkpoint_path"], map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state_dict"])
    model.to(DEVICE)
    model.eval()
    return model


def predict_with_tta(model, loader, dataset_name):
    all_probabilities = []
    model.eval()

    with torch.no_grad():
        for batch in tqdm(loader, desc=f"Predict {dataset_name}"):
            images = batch[0] if isinstance(batch, (list, tuple)) else batch
            images = images.to(DEVICE)

            logits_list = [model(images)]

            if TTA_ENABLED:
                logits_list.append(model(torch.flip(images, dims=[3])))

                if dataset_name not in NO_VFLIP_DATASETS:
                    logits_list.append(model(torch.flip(images, dims=[2])))

            probabilities = torch.stack(
                [torch.softmax(logits, dim=1) for logits in logits_list],
                dim=0,
            ).mean(dim=0)

            all_probabilities.append(probabilities.cpu().numpy())

    probabilities = np.concatenate(all_probabilities, axis=0)
    return probabilities.argmax(axis=1), probabilities


test_predictions = {}
test_probabilities = {}

for dataset_name in datasets_list:
    model = load_best_model(dataset_name)
    predictions, probabilities = predict_with_tta(
        model,
        training_outputs[dataset_name]["test_loader"],
        dataset_name,
    )
    test_predictions[dataset_name] = predictions
    test_probabilities[dataset_name] = probabilities
    print(dataset_name, predictions.shape, probabilities.shape)


timestamp = datetime.now(UTC).strftime("%Y%m%d_%H%M%S")
expected_datasets = set(DATASET_CONFIGS.keys())
provided_datasets = set(test_predictions.keys())

if provided_datasets != expected_datasets:
    missing = sorted(expected_datasets - provided_datasets)
    extra = sorted(provided_datasets - expected_datasets)

    print("=" * 80)
    print("PARTIAL RUN DETECTED — skipping final Kaggle submission CSV.")
    print("This is expected for smoke runs such as DATASETS_TO_RUN = ['pathmnist'].")
    print(f"Provided datasets: {sorted(provided_datasets)}")
    print(f"Missing datasets: {missing}")
    print(f"Extra datasets: {extra}")
    print("To create a valid competition submission, rerun with DATASETS_TO_RUN = 'all'.")
    print("=" * 80)

    submission_path = None
    submission_df = None

else:
    submission_path = SUBMISSION_DIR / f"submission_{RUN_NAME}_{timestamp}.csv"
    submission_df = build_submission_csv(test_predictions, submission_path)

    assert list(submission_df.columns) == ["id", "id_image_in_task", "task_name", "label"]
    assert submission_df["id"].is_monotonic_increasing
    assert set(submission_df["task_name"].unique()) == expected_datasets

    print("Saved submission:", submission_path)
    display(submission_df.head())
# Out:
# Predict pathmnist:   0%|          | 0/57 [00:00<?, ?it/s]
# pathmnist (7180,) (7180, 9)
# Predict dermamnist:   0%|          | 0/16 [00:00<?, ?it/s]
# dermamnist (2005,) (2005, 7)
# Predict octmnist:   0%|          | 0/8 [00:00<?, ?it/s]
# octmnist (1000,) (1000, 4)
# Predict pneumoniamnist:   0%|          | 0/5 [00:00<?, ?it/s]
# pneumoniamnist (624,) (624, 2)
# Predict retinamnist:   0%|          | 0/4 [00:00<?, ?it/s]
# retinamnist (400,) (400, 5)
# Predict breastmnist:   0%|          | 0/2 [00:00<?, ?it/s]
# breastmnist (156,) (156, 2)
# Predict bloodmnist:   0%|          | 0/27 [00:00<?, ?it/s]
# bloodmnist (3421,) (3421, 8)
# Predict tissuemnist:   0%|          | 0/370 [00:00<?, ?it/s]
# tissuemnist (47280,) (47280, 8)
# Predict organamnist:   0%|          | 0/139 [00:00<?, ?it/s]
# organamnist (17778,) (17778, 11)
# Predict organcmnist:   0%|          | 0/65 [00:00<?, ?it/s]
# organcmnist (8268,) (8268, 11)
# Predict organsmnist:   0%|          | 0/69 [00:00<?, ?it/s]
# organsmnist (8829,) (8829, 11)
# Saved submission: /kaggle/working/submissions/submission_effv2s_weighted_ce_20260521_104336.csv
#    id  id_image_in_task  task_name  label
# 0   0                 0  pathmnist      8
# 1   1                 1  pathmnist      4
# 2   2                 2  pathmnist      4
# 3   3                 3  pathmnist      8
# 4   4                 4  pathmnist      4

# %%
# K-08 Save results/config
# Works for both full runs and partial smoke runs.

import json
import shutil

def safe_get(name, default=None):
    return globals().get(name, default)


export_dir = WORKING_DIR / f"exports_{RUN_NAME}_{timestamp}"
export_dir.mkdir(parents=True, exist_ok=True)

results_path = RESULTS_DIR / f"results_{RUN_NAME}_{timestamp}.csv"
results_df = pd.DataFrame(results_rows)
results_df.to_csv(results_path, index=False)

run_config = {
    "run_name": safe_get("RUN_NAME"),
    "timestamp": timestamp,
    "datasets_to_run": safe_get("DATASETS_TO_RUN"),
    "datasets_resolved": datasets_list,
    "datasets_completed": list(test_predictions.keys()),
    "model_name": safe_get("MODEL_NAME"),
    "image_size": safe_get("IMAGE_SIZE"),
    "phase1_epochs": safe_get("PHASE1_EPOCHS"),
    "phase2_epochs": safe_get("PHASE2_EPOCHS"),
    "patience": safe_get("PATIENCE"),
    "backbone_lr": safe_get("BACKBONE_LR"),
    "head_lr": safe_get("HEAD_LR"),
    "weight_decay": safe_get("WEIGHT_DECAY"),
    "batch_size": safe_get("BATCH_SIZE"),
    "aug_level": safe_get("AUG_LEVEL"),
    "loss_type": safe_get("LOSS_TYPE"),
    "focal_gamma": safe_get("FOCAL_GAMMA") if safe_get("LOSS_TYPE") == "focal" else None,
    "scheduler": safe_get("SCHEDULER"),
    "seed": safe_get("SEED"),
    "use_trainval": safe_get("USE_TRAINVAL"),
    "tta_enabled": safe_get("TTA_ENABLED"),
    "harmonic_mean_val": float(harmonic_mean_f1),
    "partial_run": submission_path is None,
    "data_root": bc.BASE_CONFIG["data_root"],
    "repo_url": REPO_URL,
}

config_path = RESULTS_DIR / f"run_config_{RUN_NAME}_{timestamp}.json"
with open(config_path, "w", encoding="utf-8") as f:
    json.dump(run_config, f, indent=2)

submission_name = (
    submission_path.name
    if submission_path is not None
    else "NO_SUBMISSION_PARTIAL_RUN"
)

submission_log = pd.DataFrame(
    [
        {
            "version": RUN_NAME,
            "timestamp": timestamp,
            "public_score": "",
            "key_changes": f"{MODEL_NAME}, {LOSS_TYPE}, TTA={TTA_ENABLED}",
            "notes": (
                f"validation_harmonic_mean={harmonic_mean_f1:.6f}; "
                f"submission={submission_name}"
            ),
        }
    ]
)

submission_log_path = RESULTS_DIR / f"submission_log_{RUN_NAME}_{timestamp}.csv"
submission_log.to_csv(submission_log_path, index=False)

files_to_copy = [
    results_path,
    config_path,
    submission_log_path,
]

if submission_path is not None:
    files_to_copy.append(submission_path)

for path in files_to_copy:
    shutil.copy2(path, export_dir / Path(path).name)

print("=" * 80)
print("EXPORT COMPLETE")
print("=" * 80)
print(f"Export directory: {export_dir}")
print()
print("Files saved:")
for path in sorted(export_dir.iterdir()):
    print(" -", path.name)

print()
print("=" * 80)
print("FILES TO DOWNLOAD TO LOCAL")
print("=" * 80)
print(f"[REQUIRED] {results_path}")
print(f"[REQUIRED] {config_path}")
print(f"[REQUIRED] {submission_log_path}")

if submission_path is not None:
    print(f"[REQUIRED] {submission_path}")
else:
    print("[SKIPPED] No submission CSV created because this was a partial smoke run.")

print()
print("=" * 80)
print("FILES TO NOT COMMIT")
print("=" * 80)
print("*.pth checkpoint files")
print("raw data")
print("large .npy probability files unless explicitly needed for TASK-009")
# Out:
# ================================================================================
# EXPORT COMPLETE
# ================================================================================
# Export directory: /kaggle/working/exports_effv2s_weighted_ce_20260521_104336
#
# Files saved:
#  - results_effv2s_weighted_ce_20260521_104336.csv
#  - run_config_effv2s_weighted_ce_20260521_104336.json
#  - submission_effv2s_weighted_ce_20260521_104336.csv
#  - submission_log_effv2s_weighted_ce_20260521_104336.csv
#
# ================================================================================
# FILES TO DOWNLOAD TO LOCAL
# ================================================================================
# [REQUIRED] /kaggle/working/results/results_effv2s_weighted_ce_20260521_104336.csv
# [REQUIRED] /kaggle/working/results/run_config_effv2s_weighted_ce_20260521_104336.json
# [REQUIRED] /kaggle/working/results/submission_log_effv2s_weighted_ce_20260521_104336.csv
# [REQUIRED] /kaggle/working/submissions/submission_effv2s_weighted_ce_20260521_104336.csv
#
# ================================================================================
# FILES TO NOT COMMIT
# ================================================================================
# *.pth checkpoint files
# raw data
# large .npy probability files unless explicitly needed for TASK-009

# %%
# K-09 Manual Kaggle submit
# Run only for full 11-dataset runs, after K-07 created a valid submission CSV.

if submission_path is None:
    print("No submission_path exists because this was a partial run. Skipping Kaggle submit.")
else:
    print(f"Ready to submit: {submission_path}")
    print("Uncomment the subprocess.run block below when you want to submit.")

    # import subprocess
    # result = subprocess.run(
    #     [
    #         "kaggle",
    #         "competitions",
    #         "submit",
    #         "-c",
    #         "tensor-reloaded-multi-task-med-mnist",
    #         "-f",
    #         str(submission_path),
    #         "-m",
    #         f"{RUN_NAME} hm_val={harmonic_mean_f1:.4f}",
    #     ],
    #     capture_output=True,
    #     text=True,
    # )
    # print(result.stdout)
    # if result.returncode != 0:
    #     print("ERROR:", result.stderr)
# Out:
# Ready to submit: /kaggle/working/submissions/submission_effv2s_weighted_ce_20260521_104336.csv
# Uncomment the subprocess.run block below when you want to submit.
